# %%
# Change Working Directory
import os
os.chdir("../code/")

# %% [markdown]
# ## My Implementation

# %%
from DecisionTree import DecisionTree
import numpy as np

# %%
test_data = np.array([
    [1, 1, 7, 0],
    [1, 0, 12, 0],
    [0, 1, 18, 1],
    [0, 1, 35, 1],
    [1, 1, 38, 1],
    [1, 0, 50, 0],
    [0, 0, 83, 0]
], dtype=object)

# %%
test1 = DecisionTree.DecisionTree()
test1.build_tree(data=test_data)

# %%
test1.print_tree()
# Out:
# Feature 1 < 0.5
# Left:
#   Leaf: 0
# Right:
#   Feature 2 < 12.5
#   Left:
#     Leaf: 0
#   Right:
#     Leaf: 1

# %% [markdown]
# ## Sklearn Implementation

# %%
test_data = np.array([
    [1, 1, 7, "No Likes"],
    [1, 0, 12, "No Likes"],
    [0, 1, 18, "Likes"],
    [0, 1, 35, "Likes"],
    [1, 1, 38, "Likes"],
    [1, 0, 50, "No Likes"],
    [0, 0, 83, "No Likes"]
], dtype=object)

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
clf = DecisionTreeClassifier()

clf = clf.fit(test_data[:,0:3], test_data[:,3:4])

# %% [markdown]
# ## Comparison

# %%
from sklearn.tree import plot_tree

plot_tree(clf)
# Out:
# [Text(0.4, 0.8333333333333334, 'x[1] <= 0.5\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.30000000000000004, 0.6666666666666667, 'True  '),
#  Text(0.6, 0.5, 'x[2] <= 12.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.5, 0.6666666666666667, '  False'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]')]

# %%
test1.print_tree()
# Out:
# Feature 1 < 0.5
# Left:
#   Leaf: 0
# Right:
#   Feature 2 < 12.5
#   Left:
#     Leaf: 0
#   Right:
#     Leaf: 1

# %% [markdown]
# My implementation seems to work so far :). We'll try next with the Titanic Dataset before moving on
